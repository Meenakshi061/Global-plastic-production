# %% [markdown]
# #  To study how plastic production has increased over time, which countries make the most, and how it affects the environment."

# %%
import pandas as pd  # data  Library   # Data manipulation & analysis.
import numpy as np  #Mathematical operation
import matplotlib.pyplot as plt # Graphs aur charts
import seaborn as sns # Stylish and easy plots

# %%
df=pd.read_csv(r'C:\Users\Lenovo\Desktop\python  Ml crt\New project Global plastic pollution\global-plastics-production.csv') # data  read ke liye

# %% [markdown]
# # viewing data

# %%
df
# Out:
#    Entity      Code  Year  Global plastics production (million tonnes)
# 0   World  OWID_WRL  1950                                      2000000
# 1   World  OWID_WRL  1951                                      2000000
# 2   World  OWID_WRL  1952                                      2000000
# 3   World  OWID_WRL  1953                                      3000000
# 4   World  OWID_WRL  1954                                      3000000
# ..    ...       ...   ...                                          ...
# 61  World  OWID_WRL  2011                                    325000000
# 62  World  OWID_WRL  2012                                    338000000
# 63  World  OWID_WRL  2013                                    352000000
# 64  World  OWID_WRL  2014                                    367000000
# 65  World  OWID_WRL  2015                                    381000000
#
# [66 rows x 4 columns]

# %%
df.head()
# Out:
#   Entity      Code  Year  Global plastics production (million tonnes)
# 0  World  OWID_WRL  1950                                      2000000
# 1  World  OWID_WRL  1951                                      2000000
# 2  World  OWID_WRL  1952                                      2000000
# 3  World  OWID_WRL  1953                                      3000000
# 4  World  OWID_WRL  1954                                      3000000

# %%
df .tail()
# Out:
#    Entity      Code  Year  Global plastics production (million tonnes)
# 61  World  OWID_WRL  2011                                    325000000
# 62  World  OWID_WRL  2012                                    338000000
# 63  World  OWID_WRL  2013                                    352000000
# 64  World  OWID_WRL  2014                                    367000000
# 65  World  OWID_WRL  2015                                    381000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 4 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Entity                                       66 non-null     object
#  1   Code                                         66 non-null     object
#  2   Year                                         66 non-null     int64
#  3   Global plastics production (million tonnes)  66 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#               Year  Global plastics production (million tonnes)
# count    66.000000                                 6.600000e+01
# mean   1982.500000                                 1.185303e+08
# std      19.196354                                 1.126182e+08
# min    1950.000000                                 2.000000e+06
# 25%    1966.250000                                 2.075000e+07
# 50%    1982.500000                                 7.650000e+07
# 75%    1998.750000                                 1.985000e+08
# max    2015.000000                                 3.810000e+08

# %%
df.dtypes
# Out:
# Entity                                         object
# Code                                           object
# Year                                            int64
# Global plastics production (million tonnes)     int64
# dtype: object

# %%
df.shape
# Out:
# (66, 4)

# %%
df.iloc[0]
# Out:
# Entity                                            World
# Code                                           OWID_WRL
# Year                                               1950
# Global plastics production (million tonnes)     2000000
# Name: 0, dtype: object

# %% [markdown]
# # duplicated values remove

# %%
df.isnull()
# Out:
#     Entity   Code   Year  Global plastics production (million tonnes)
# 0    False  False  False                                        False
# 1    False  False  False                                        False
# 2    False  False  False                                        False
# 3    False  False  False                                        False
# 4    False  False  False                                        False
# ..     ...    ...    ...                                          ...
# 61   False  False  False                                        False
# 62   False  False  False                                        False
# 63   False  False  False                                        False
# 64   False  False  False                                        False
# 65   False  False  False                                        False
#
# [66 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Entity                                         0
# Code                                           0
# Year                                           0
# Global plastics production (million tonnes)    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#    Entity      Code  Year  Global plastics production (million tonnes)
# 0   World  OWID_WRL  1950                                      2000000
# 1   World  OWID_WRL  1951                                      2000000
# 2   World  OWID_WRL  1952                                      2000000
# 3   World  OWID_WRL  1953                                      3000000
# 4   World  OWID_WRL  1954                                      3000000
# ..    ...       ...   ...                                          ...
# 61  World  OWID_WRL  2011                                    325000000
# 62  World  OWID_WRL  2012                                    338000000
# 63  World  OWID_WRL  2013                                    352000000
# 64  World  OWID_WRL  2014                                    367000000
# 65  World  OWID_WRL  2015                                    381000000
#
# [66 rows x 4 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(inplace=True)# delete the null value

# %%
df.fillna(0)
# Out:
#    Entity      Code  Year  Global plastics production (million tonnes)
# 0   World  OWID_WRL  1950                                      2000000
# 1   World  OWID_WRL  1951                                      2000000
# 2   World  OWID_WRL  1952                                      2000000
# 3   World  OWID_WRL  1953                                      3000000
# 4   World  OWID_WRL  1954                                      3000000
# ..    ...       ...   ...                                          ...
# 61  World  OWID_WRL  2011                                    325000000
# 62  World  OWID_WRL  2012                                    338000000
# 63  World  OWID_WRL  2013                                    352000000
# 64  World  OWID_WRL  2014                                    367000000
# 65  World  OWID_WRL  2015                                    381000000
#
# [66 rows x 4 columns]
